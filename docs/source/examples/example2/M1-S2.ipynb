# %%
# %matplotlib ipympl

# %% [markdown]
# ## Baseline fitting

# %%
fname = 'output/AlFA_0_onoff/20220805/AlFA_0_onoff-M01_W-20220805-S_ps.hdf5'

# %%
# !h5ls -r $fname
# Out:
# /                        Group
# /0                       Group
# /0/DATA                  Soft Link {/S/Ta}
# /Header                  Group
# /S                       Group
# /S/Ta                    Dataset {2, 1, 4195}
# /S/Tcal                  Dataset {1, 4195, 2}
# /S/dec                   Dataset {1}
# /S/freq                  Dataset {4195}
# /S/is_delay              Dataset {1}
# /S/is_on                 Dataset {1}
# /S/mjd                   Dataset {1}
# /S/next_to_cal           Dataset {1}
# /S/ra                    Dataset {1}

# %%
# %run -m hifast.bld $fname --frange 1380 1400 -i -f
# Out:
# ...
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# ...
# outdir: output/AlFA_0_onoff/20220805
# Please run 'save()' in the notebook cell to save your results

# %%
save()
# Out:
# Please ensure you have adjusted the parameters for each `polar`, otherwise you will get nan vaules in the file
# Saving...
# Saved to output/AlFA_0_onoff/20220805/AlFA_0_onoff-M01_W-20220805-S_ps-bld.hdf5

# %% [markdown]
# ## fitting 1-MHz standwaving

# %%
# use baselined file: *-bld.hdf5

# %%
fname = 'output/AlFA_0_onoff/20220805/AlFA_0_onoff-M01_W-20220805-S_ps-bld.hdf5'

# %%
# %run -m hifast.sw  $fname --frange 1382 1395 -i -f
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...
# outdir: output/AlFA_0_onoff/20220805
# Please run 'save()' in the notebook cell to save your results

# %%
save()
# Out:
# Please ensure you have adjusted the parameters for each `polar`, otherwise you will get nan vaules in the file
# Saving...
# Saved to output/AlFA_0_onoff/20220805/AlFA_0_onoff-M01_W-20220805-S_ps-bld-sw.hdf5

# %%
fname = 'output/AlFA_0_onoff/20220805/AlFA_0_onoff-M01_W-20220805-S_ps-bld-sw.hdf5'

# %%
# !h5ls -r $fname
# Out:
# /                        Group
# /0                       Group
# /0/DATA                  Soft Link {/S/Ta}
# /Header                  Group
# /S                       Group
# /S/Ta                    Dataset {2, 1, 1703}
# /S/Tcal                  Dataset {1, 1703, 2}
# /S/dec                   Dataset {1}
# /S/freq                  Dataset {1703}
# /S/is_delay              Dataset {1}
# /S/is_on                 Dataset {1}
# /S/mjd                   Dataset {1}
# /S/next_to_cal           Dataset {1}
# /S/ra                    Dataset {1}

# %%
import hifast.funcs as hf

# %%
S = hf.HFSpec(fname)

# %%
S
# Out:
# keys: ('Ta', 'Tcal', 'dec', 'freq', 'is_delay', 'is_on', 'mjd', 'next_to_cal', 'ra', 'DATA')

# %%
from matplotlib import pyplot as plt

# %%
plt.figure()
plt.plot(S.DATA[0])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
S.DATA[:]
# Out:
# array([[[-5.1987544e-02,  0.0000000e+00],
#         [-1.6938984e-02,  0.0000000e+00],
#         [-1.8412530e-02,  1.3780403e+03],
#         ...,
#         [-5.4431409e-03,  0.0000000e+00],
#         [-4.3365687e-02,  0.0000000e+00],
#         [ 1.1072174e-02,  0.0000000e+00]]], dtype=float32)
