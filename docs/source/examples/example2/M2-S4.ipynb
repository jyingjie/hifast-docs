# %%
# %matplotlib ipympl

# %% [markdown]
# ## Baseline fitting

# %%
fname = 'output2/AlFA_0_onoff/20220805/AlFA_0_onoff-M01_W-20220805-specs_T-bld_p-sw_nobld-flux-ps.hdf5'

# %%
# !h5ls -r $fname
# Out:
# /                        Group
# /0                       Group
# /0/DATA                  Soft Link {/S/flux}
# /Header                  Group
# /S                       Group
# /S/Ta_ref                Dataset {2, 1, 2884}
# /S/Ta_src                Dataset {2, 1, 2884}
# /S/Tcal                  Dataset {1, 2884, 2}
# /S/dec                   Dataset {1}
# /S/flux                  Dataset {2, 1, 2884}
# /S/freq                  Dataset {2884}
# /S/is_delay              Dataset {1}
# /S/is_extrapo            Dataset {538}
# /S/is_on                 Dataset {1}
# /S/mjd                   Dataset {1}
# /S/next_to_cal           Dataset {1}
# /S/ra                    Dataset {1}

# %%
# %run -m hifast.bld $fname --frange 1380 1400 -i -f
# Out:
# ...
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# ...
# outdir: output2/AlFA_0_onoff/20220805
# Please run 'save()' in the notebook cell to save your results

# %%
save()
# Out:
# Please ensure you have adjusted the parameters for each `polar`, otherwise you will get nan vaules in the file
# Saving...
# Saved to output2/AlFA_0_onoff/20220805/AlFA_0_onoff-M01_W-20220805-specs_T-bld_p-sw_nobld-flux-ps-bld.hdf5

# %%
import hifast.funcs as hf

# %%
fname = 'output2/AlFA_0_onoff/20220805/AlFA_0_onoff-M01_W-20220805-specs_T-bld_p-sw_nobld-flux-ps-bld.hdf5'

# %%
S = hf.HFSpec(fname)

# %%
S
# Out:
# keys: ('Tcal', 'dec', 'flux', 'freq', 'is_delay', 'is_extrapo', 'is_on', 'mjd', 'next_to_cal', 'ra', 'DATA')

# %%
from matplotlib import pyplot as plt

# %%
plt.figure()
plt.plot(S.DATA[0])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
S.DATA[:]
# Out:
# array([[[-0.00270173, -0.00174202],
#         [-0.00083298, -0.0031247 ],
#         [-0.00100294,  0.00011556],
#         ...,
#         [ 0.0012708 ,  0.00147297],
#         [-0.0015876 , -0.00081714],
#         [ 0.000536  , -0.00131684]]], dtype=float32)
